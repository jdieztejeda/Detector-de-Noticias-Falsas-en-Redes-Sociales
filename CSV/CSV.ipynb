# %%
myDF = spark.read.option('sep', ',').option('multiline', 'true').option('header','true').csv('file:/home/student/Downloads/WELFake_Dataset.csv')
myDF.printSchema()
myDF.show(3)
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- label: string (nullable = true)
#
# +---+--------------------+--------------------+-----+
# |_c0|               title|                text|label|
# +---+--------------------+--------------------+-----+
# |  0|LAW ENFORCEMENT O...|No comment is exp...|    1|
# |  1|                null|Did they post the...|    1|
# |  2|UNBELIEVABLE! OBA...| Now, most of the...|    1|
# +---+--------------------+--------------------+-----+
# only showing top 3 rows
# 2022-11-24 00:59:59,540 WARN csv.CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , title, text, label
#  Schema: _c0, title, text, label
# Expected: _c0 but found:
# CSV file: file:///home/student/Downloads/WELFake_Dataset.csv

# %%
welDF= spark.read.table("project.News")
welDF.printSchema()
welDF.show(3)
# Out:
# 2022-11-24 01:00:37,262 WARN conf.HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 2022-11-24 01:00:37,262 WARN conf.HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# 2022-11-24 01:00:38,227 WARN metastore.ObjectStore: Failed to get database global_temp, returning NoSuchObjectException
# root
#  |-- id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- author: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- label: string (nullable = true)
#
# +---+--------------------+------------------+--------------------+-----+
# | id|               title|            author|                text|label|
# +---+--------------------+------------------+--------------------+-----+
# |  1|FLYNN: Hillary Cl...|   Daniel J. Flynn|Ever get the feel...|    0|
# |  2|Why the Truth Mig...|Consortiumnews.com|Why the Truth Mig...|    1|
# |  3|15 Civilians Kill...|   Jessica Purkiss|Videos 15 Civilia...|    1|
# ...

# %%
betterDF = welDF.select("id", "title", "text", "label")
betterDF.printSchema()
betterDF.show(3)
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- label: string (nullable = true)
#
# +---+--------------------+--------------------+-----+
# | id|               title|                text|label|
# +---+--------------------+--------------------+-----+
# |  1|FLYNN: Hillary Cl...|Ever get the feel...|    0|
# |  2|Why the Truth Mig...|Why the Truth Mig...|    1|
# |  3|15 Civilians Kill...|Videos 15 Civilia...|    1|
# +---+--------------------+--------------------+-----+
# only showing top 3 rows

# %%
nuevo= betterDF.union(myDF)
nuevo.printSchema()
nuevo.show(3)
nuevo.count()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- label: string (nullable = true)
#
# +---+--------------------+--------------------+-----+
# | id|               title|                text|label|
# +---+--------------------+--------------------+-----+
# |  1|FLYNN: Hillary Cl...|Ever get the feel...|    0|
# |  2|Why the Truth Mig...|Why the Truth Mig...|    1|
# |  3|15 Civilians Kill...|Videos 15 Civilia...|    1|
# +---+--------------------+--------------------+-----+
# only showing top 3 rows
# 98669

# %%
holi.write.saveAsTable("project.finalNews")
# Out:
# 2022-11-23 23:52:42,148 WARN lazy.LazyStruct: Extra bytes detected at the end of the row! Ignoring similar problems.
# 2022-11-23 23:52:44,951 WARN session.SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# 2022-11-23 23:52:44,989 WARN conf.HiveConf: HiveConf of name hive.internal.ss.authz.settings.applied.marker does not exist
# 2022-11-23 23:52:44,989 WARN conf.HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 2022-11-23 23:52:44,989 WARN conf.HiveConf: HiveConf of name hive.stats.retries.wait does not exist

# %%
hola= nuevo.select("title", "text", "label")
hola.printSchema()
hola.show(3)
hola.count()
# Out:
# root
#  |-- title: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- label: string (nullable = true)
#
# +--------------------+--------------------+-----+
# |               title|                text|label|
# +--------------------+--------------------+-----+
# |FLYNN: Hillary Cl...|Ever get the feel...|    0|
# |Why the Truth Mig...|Why the Truth Mig...|    1|
# |15 Civilians Kill...|Videos 15 Civilia...|    1|
# +--------------------+--------------------+-----+
# only showing top 3 rows
# 98669

# %%
holi.write.option('header', 'false').option("sep","\t").csv('file:/home/student/Data/Project/junto.csv')
# Out:
# 2022-11-23 03:22:43,000 WARN lazy.LazyStruct: Extra bytes detected at the end of the row! Ignoring similar problems.

# %%
# Out:
# [Row(title='Putin offers transcript to prove Trump did not pass Russia secrets', text='SOCHI/MOSCOW (Reuters) - Vladimir Putin said on Wednesday that U.S. President Donald Trump had not divulged any secrets during a meeting in Washington with Russian officials and offered to prove it by supplying Congress with a transcript. But a leading U.S. Republican politician said he would have little faith in any notes Putin might supply. Two U.S. officials said on Monday Trump had disclosed classified information about a planned Islamic State operation to Russian Foreign Minister Sergei Lavrov when they met last week, plunging the White House into a fresh controversy just four months into Trump’s tenure. Trump, whose administration has been dogged by allegations that Russia helped him win the White House and that he and his allies are too cozy with Moscow, has defended his decision to discuss intelligence with the Russians after media reports of the meeting alarmed some U.S. and foreign politi
# ...

# %%
hola.show(3)
# Out:
# +--------------------+--------------------+-----+
# |               title|                text|label|
# +--------------------+--------------------+-----+
# |FLYNN: Hillary Cl...|Ever get the feel...|    0|
# |Why the Truth Mig...|Why the Truth Mig...|    1|
# |15 Civilians Kill...|Videos 15 Civilia...|    1|
# +--------------------+--------------------+-----+
# only showing top 3 rows

# %%
holi = hola.filter((hola.label == 0) | (hola.label == 1))
holi.printSchema()
holi.show(3)
holi.count()
# Out:
# root
#  |-- title: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- label: string (nullable = true)
#
# +--------------------+--------------------+-----+
# |               title|                text|label|
# +--------------------+--------------------+-----+
# |FLYNN: Hillary Cl...|Ever get the feel...|    0|
# |Why the Truth Mig...|Why the Truth Mig...|    1|
# |15 Civilians Kill...|Videos 15 Civilia...|    1|
# +--------------------+--------------------+-----+
# only showing top 3 rows
# 2022-11-24 01:00:59,897 WARN lazy.LazyStruct: Extra bytes detected at the end of the row! Ignoring similar problems.
# 87892

# %%
import pandas as pd
fin = holi.toPandas()
print(fin)
# Out:
# 2022-11-24 01:01:03,356 WARN lazy.LazyStruct: Extra bytes detected at the end of the row! Ignoring similar problems.
#                                                    title  \
# 0      FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 1                      Why the Truth Might Get You Fired
# 2      15 Civilians Killed In Single US Airstrike Hav...
# 3      Iranian woman jailed for fictional unpublished...
# 4      Jackie Mason: Hollywood Would Love Trump if He...
# ...                                                  ...
# 87887  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 87888  Russians steal research on Trump in hack of U....
# 87889   WATCH: Giuliani Demands That Democrats Apolog...
# 87890  Trump tussle gives unpopular Mexican leader mu...
# 87891  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text label
# 0      Ever get the feeling your life circles the rou...     0
# ...

# %%
ultimo.to_csv('ultimo2.csv',sep='\t')

# %%
fin['junto']= fin['title']+' '+fin['text']
print(fin)
# Out:
#                                                                                                                               title  \
# 0      FLYNN: Hillary Clinton, Big Woman on Campus - Breitbart
# 1      Why the Truth Might Get You Fired
# 2      15 Civilians Killed In Single US Airstrike Have Been Identified
# 3      Iranian woman jailed for fictional unpublished story about woman stoned to death for adultery
# 4      Jackie Mason: Hollywood Would Love Trump if He Bombed North Korea over Lack of Trans Bathrooms (Exclusive Video) - Breitbart
# ...                                                                                                                             ...
# 87887  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS Used For Lavish Wedding Of “Spoiled Brat” Chelsea Clinton
# 87888  Russians steal research on Trump in hack of U.S. Democratic Party
# 87889   WATCH: Giuliani Demands That Democrats Apologize For Trump’s Racist Birtherism
# ...

# %%
ultimo = fin[['junto', 'label']].copy()
print(ultimo)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
pd.set_option('display.max_colwidth', -1)
ultimo.head(20)
# Out:
# /tmp/ipykernel_4973/3871861369.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# ...
